# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Set the path to the GeoPackage file
gpkg_file = "data/cph/copenhagen_zoning.gpkg"  # Replace with your GeoPackage file path

# Load the GeoPackage into a GeoDataFrame
gdf = gpd.read_file(gpkg_file)

# Display the first few rows of the GeoDataFrame
print(gdf.head())

# Optionally, plot the data
gdf.plot(figsize=(10, 10), alpha=0.5, edgecolor='k')
plt.show()
# Out:
# c:\Users\arthu\AppData\Local\Programs\Python\Python310\lib\site-packages\pyogrio\geopandas.py:265: UserWarning: More than one layer found in 'copenhagen_zoning.gpkg': 'DK001L2_KOBENHAVN_UA2018' (default), 'DK001L2_KOBENHAVN_UA2018_Boundary', 'DK001L2_KOBENHAVN_UA2018_UrbanCore'. Specify layer parameter to avoid this warning.
#   result = read_func(
#   country   fua_name fua_code code_2018  \
# 0      DK  København  DK001L2     11220
# 1      DK  København  DK001L2     11210
# 2      DK  København  DK001L2     11210
# 3      DK  København  DK001L2     11210
# 4      DK  København  DK001L2     11210
#
#                                           class_2018 prod_date     identifier  \
# 0  Discontinuous medium density urban fabric (S.L...   2020-06  11816-DK001L2
# 1  Discontinuous dense urban fabric (S.L. : 50% -...   2020-06   6271-DK001L2
# 2  Discontinuous dense urban fabric (S.L. : 50% -...   2020-06   5640-DK001L2
# 3  Discontinuous dense urban fabric (S.L. : 50% -...   2020-06   6973-DK001L2
# 4  Discontinuous dense urban fabric (S.L. : 50% -...   2020-06   7738-DK001L2
#
#      perimeter           area comment  Pop2018  \
# 0   281.985172    4778.321045    None       15
# 1  8462.944932  282764.709119    None      131
# 2  3693.692266   83629.268948    None      325
# 3   426.180020   11081.224831    None      159
# 4   387.313644    8451.604785    None       43
#
#                                             geometry
# 0  MULTIPOLYGON (((4463296.203 3608489.238, 44633...
# 1  MULTIPOLYGON (((4469000 3618588.419, 4468818.1...
# 2  MULTIPOLYGON (((4468000 3619592.246, 4468005.8...
# 3  MULTIPOLYGON (((4479385.557 3622923.089, 44793...
# 4  MULTIPOLYGON (((4479938.549 3629046.394, 44797...

# %%
import geopandas as gpd

# Set the path to the GeoPackage file
gpkg_file = "data/ams/amsterdam_zoning.gpkg"  # Replace with your GeoPackage file path

# Load the GeoPackage into a GeoDataFrame
gdf = gpd.read_file(gpkg_file)

# Display the first few rows of the GeoDataFrame
print(gdf.head())

# Optionally, plot the data
gdf.plot(figsize=(10, 10), alpha=0.5, edgecolor='k')
plt.show()
# Out:
# c:\Users\arthu\AppData\Local\Programs\Python\Python310\lib\site-packages\pyogrio\geopandas.py:265: UserWarning: More than one layer found in 'amsterdam_zoning.gpkg': 'NL002L3_AMSTERDAM_UA2018' (default), 'NL002L3_AMSTERDAM_UA2018_Boundary', 'NL002L3_AMSTERDAM_UA2018_UrbanCore'. Specify layer parameter to avoid this warning.
#   result = read_func(
#   country   fua_name fua_code code_2018  \
# 0      NL  Amsterdam  NL002L3     11100
# 1      NL  Amsterdam  NL002L3     11220
# 2      NL  Amsterdam  NL002L3     11100
# 3      NL  Amsterdam  NL002L3     11210
# 4      NL  Amsterdam  NL002L3     11220
#
#                                           class_2018 prod_date     identifier  \
# 0             Continuous urban fabric (S.L. : > 80%)   2020-09   1984-NL002L3
# 1  Discontinuous medium density urban fabric (S.L...   2020-09  21286-NL002L3
# 2             Continuous urban fabric (S.L. : > 80%)   2020-09   1631-NL002L3
# 3  Discontinuous dense urban fabric (S.L. : 50% -...   2020-09  15185-NL002L3
# 4  Discontinuous medium density urban fabric (S.L...   2020-09  21496-NL002L3
#
#      perimeter          area comment  Pop2018  \
# 0   236.566668   3311.003470    None       60
# 1   986.670372  20223.078131    None      166
# 2   298.725443   5274.183057    None      105
# 3   263.364524   1246.134188    None       12
# 4  1752.521176  33006.308917    None      482
#
#                                             geometry
# 0  MULTIPOLYGON (((3977068.264 3259854.957, 39771...
# 1  MULTIPOLYGON (((3979533.408 3257265.83, 397954...
# 2  MULTIPOLYGON (((3977985.908 3257462.858, 39779...
# 3  MULTIPOLYGON (((3985056.716 3258575.877, 39850...
# 4  MULTIPOLYGON (((3978284.29 3259825.736, 397823...

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import os
import pandas as pd

# Set the path to the directory containing your shapefiles
directory = "data/sp/"  # Replace with your directory path

# List of shapefiles you want to load
shapefiles = [
    "AC_1.shp", "AC_2.shp", "PCA_CANT.shp", "VETOS_TODOS.shp", "ZC_a.shp", "ZC.shp",
    "ZCOR_1.shp", "ZCOR_2.shp", "ZCOR_3.shp", "ZCOR_a.shp", "ZC_ZEIS.shp", "ZDE_1.shp",
    "ZDE_2.shp", "ZEIS_1.shp", "ZEIS_2.shp", "ZEIS_3.shp", "ZEIS_4.shp", "ZEIS_5.shp",
    "ZEMP.shp", "ZEM.shp", "ZEPAM.shp", "ZEP.shp", "ZER_1.shp", "ZER_2.shp", "ZER_a.shp",
    "ZEU_a.shp", "ZEUP_a.shp", "ZEUP_u.shp", "ZEU_u.shp", "ZM_a.shp", "ZMIS_a.shp",
    "ZMIS_u.shp", "ZM_u.shp", "ZOE.shp", "ZPDS_r.shp", "ZPDS_u.shp", "ZPI_1.shp",
    "ZPI_2.shp", "ZPR.shp"
]

# Initialize an empty list to hold GeoDataFrames
gdfs = []

# Loop through the shapefiles, read them, and append to the list
for shp in shapefiles:
    filepath = os.path.join(directory, shp)
    try:
        # Read the shapefile into a GeoDataFrame
        gdf = gpd.read_file(filepath)
        gdfs.append(gdf)
    except Exception as e:
        print(f"Could not read {shp}: {e}")

# Concatenate all GeoDataFrames into one
if gdfs:
    combined_gdf = gpd.GeoDataFrame(pd.concat(gdfs, ignore_index=True))

    # Plot the combined GeoDataFrame
    combined_gdf.plot(figsize=(15, 10))
    plt.show()
else:
    print("No valid shapefiles found.")
# Out:
# c:\Users\arthu\AppData\Local\Programs\Python\Python310\lib\site-packages\pyogrio\raw.py:198: RuntimeWarning: Non closed ring detected. To avoid accepting it, set the OGR_GEOMETRY_ACCEPT_UNCLOSED_RING configuration option to NO
#   return ogr_read(
# Could not read PCA_CANT.shp: IllegalArgumentException: Points of LinearRing do not form a closed linestring

# %%
# Set the path to the directory containing your shapefiles
directory = "data/nyc/"  # Replace with your directory path

# List of shapefiles you want to load
shp_files = [
    "geo_export_7448ba33-c303-414c-95d6-be1679935dde.shp",
    "geo_export_79898409-c00f-4e11-98fe-e97580e94c8b.shp",
    "geo_export_822a1b7a-d492-441a-a1ee-4ceae7249a89.shp",
    "geo_export_8440838b-02f2-4084-956b-974e1b719a98.shp",
    "geo_export_91c4703e-b908-4625-a60e-047f586a436b.shp",
    "geo_export_ccae7519-1fc7-4412-af0d-b988d2843282.shp"
]

# Initialize an empty list to hold GeoDataFrames
gdfs = []

# Loop through the shapefiles, read them, and append to the list
for shp in shp_files:
    filepath = os.path.join(directory, shp)
    try:
        # Read the shapefile into a GeoDataFrame
        gdf = gpd.read_file(filepath)
        gdfs.append(gdf)
    except Exception as e:
        print(f"Could not read {shp}: {e}")

# Concatenate all GeoDataFrames into one
if gdfs:
    combined_gdf = gpd.GeoDataFrame(pd.concat(gdfs, ignore_index=True))

    # Plot the combined GeoDataFrame
    combined_gdf.plot(figsize=(15, 10))
    plt.show()
else:
    print("No valid shapefiles found.")
